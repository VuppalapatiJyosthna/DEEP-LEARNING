# %%
20MAI0058
Vuppalapati Jyosthna

# %%
3.
  1. read image from folder
  2.load in the numpy array or in excel (display some images) 
  3. extract feature from step using builtin fun  (top 5 image feature and its 
                                                  label)
    4. split train and test
     5. learning algorihm
      6. test (display test image with accuracy)
       7. accuracy score, Precision, recall , F1-score

# %%
 1. read image from folder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('/content/sample_data/social6.jpg', as_gray=False)
imshow(image)

# %%
 2. load in the numpy array or in excel (display some images)

# %%
from PIL import Image
from numpy import asarray
# load the image
image1 = Image.open('/content/sample_data/sociaal3.jpg')
image2 = Image.open('/content/sample_data/social1.jpg')
image3 = Image.open('/content/sample_data/social3.jpg')
image4 = Image.open('/content/sample_data/social4.jpg')
image5 = Image.open('/content/sample_data/social5.jpg')
image6 = Image.open('/content/sample_data/social6.jpg')
image7 = Image.open('/content/sample_data/social7.jpg')
image8 = Image.open('/content/sample_data/social13.jpg')
# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)

# create Pillow image
#image = Image.fromarray(data)
#print(type(image))

# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# <class 'numpy.ndarray'>
# ()
# RGB
# (341, 238)

# %%
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=341x249 at 0x7F8526DDBCD0>

# %%
image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=341x238 at 0x7F8526DD7590>

# %%
image4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=341x219 at 0x7F8526DD7410>

# %%
 3. extract feature from step using builtin fun  (top 5 image feature and its 
                                                  label)

# %%
X = np.array(image1)

# %%
X.shape
# Out:
# (249, 341, 3)

# %%
X = np.array(image2)

# %%
X.shape
# Out:
# (238, 341, 3)

# %%
X = np.array(image3)
X.shape
# Out:
# (226, 341, 3)

# %%
X = np.array(image4)
X.shape
# Out:
# (219, 341, 3)

# %%
X = np.array(image4)
X.shape
# Out:
# (219, 341, 3)

# %%
X = np.array(image5)
X.shape
# Out:
# (255, 341, 3)

# %%
y = np.array(image3)
y.shape
# Out:
# (226, 341, 3)
